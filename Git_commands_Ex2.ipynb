# %% [markdown]
# ### What remote repositories am I connected to?
#
# git remote -v

# %% [markdown]
# ```
# PMuhuri@CCASTA-HWJP0G2 MINGW64 /
# $ cd /c/AnalyzeMEPS
#
# PMuhuri@CCASTA-HWJP0G2 MINGW64 /c/AnalyzeMEPS (master)
# $ git remote -v
# origin  https://github.com/pkmedu/AnalyzeMEPS (fetch)
# origin  https://github.com/pkmedu/AnalyzeMEPS (push)
#
# PMuhuri@CCASTA-HWJP0G2 MINGW64 /c/AnalyzeMEPS (master)
# $ cd /c/sascourse
#
# PMuhuri@CCASTA-HWJP0G2 MINGW64 /c/sascourse (master)
# $ git remote -v
# origin  git@github.com:SASGateway/SASCourse.git (fetch)
# origin  git@github.com:SASGateway/SASCourse.git (push)
#
# Bit Bucket Account (CodeReveals)
# Personal email address
# Bh********DD
# ```

# %%
from IPython.display import Image
Image("c:/Data/git_remote_v.png")

# %%
from IPython.display import Image
Image("c:/Data/Bit_Bucket.png")

# %% [markdown]
#    ![](c:/Data/git_remote_v.png)
